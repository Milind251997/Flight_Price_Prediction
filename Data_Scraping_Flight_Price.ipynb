# %% [markdown]
# ### Importing Necessary Libraries

# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
import warnings
warnings.filterwarnings('ignore')
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# ### Using Chrome as Driver

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()

# %%
url = 'https://www.yatra.com/'
driver.get(url)

# %%
name = []          #name of flight        
date = []          #date of flight         
source = []        #source of the flight        
destination = []   #destination of the flight                   
dep_time = []      #departure time of the flight           
arr_time = []     #arrival time of the flight            
duration = []     #duration of the flight      
stops = []        #number of stops
price = []      #price of flight ticket

# %%
#Clicking the search button 
driver.find_element_by_xpath('//*[@id="BE_flight_flsearch_btn"]').click()
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
#27_Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
driver.find_element_by_xpath('//*[@id="Flight-APP"]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[2]').click()
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#28_Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
driver.find_element_by_xpath('//*[@id="Flight-APP"]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[2]').click()
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#29_Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[4]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
driver.find_element_by_xpath('//*[@id="Flight-APP"]/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[2]').click()
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#30_Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[5]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %% [markdown]
# ### Yatra.Com with Differrent Locations

# %%
url = 'https://www.yatra.com/'
driver.get(url)

# %%
driver.find_element_by_xpath('//*[@id="BE_flight_flsearch_btn"]').click()

# %%
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
#Mumbai_TO_Bangalore
#27_Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
#Mumbai_TO_Bangalore 
#28_Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
#Mumbai_TO_Chennai
#27_Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
#Mumbai_TO_Chennai 
#28 Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
#Mumbai_TO_Ahmedabad 
#28 Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
#Delhi_TO_Chennai 
#28 Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
#Delhi_to_Bangalore 
#27 Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[2]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %%
#Delhi_to_Bangalore 28 Nov
try:
    all_names = driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for i in all_names:
        name.append(i.text)

except NoSuchElementException:
    name.append('NaN')
    
#date
try:
    all_dates = driver.find_element_by_xpath("//*[@id='Flight-APP']/section/section[2]/section[1]/div[1]/div/div[1]/div/ul/li[3]/div/p[1]")
    linked =  driver.find_elements_by_xpath("/html/body/section[2]/section/section[2]/section[1]/div[2]/div[2]/div/div/div/div[2]/div[1]/div/div[2]/span")
    for j in range(0,len(linked)):
        date.append(all_dates.text)
except NoSuchElementException:
    date.append('NaN')
    
    
#dep_time
try:
    dep_times = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//div//div[@class = 'i-b pr']")

    for i in dep_times:
        dep_time.append(i.text)
except NoSuchElementException:
    dep_time.append('NaN')

    
#arr_time
try:
    arr_times = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[1]")

    for i in arr_times:
        arr_time.append(i.text)
except NoSuchElementException:
    arr_time.append('NaN')
    

#source
try:
    sources = driver.find_elements_by_xpath("//div[@class = 'i-b col-4 no-wrap text-right dtime col-3']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in sources:
        source.append(i.text)
except NoSuchElementException:
    source.append('NaN')
    
    
#destination
try:
    destinations = driver.find_elements_by_xpath("//div[@class = 'i-b pdd-0 text-left atime col-5']//p[@class = 'fs-10 font-lightgrey no-wrap city ellipsis']")

    for i in destinations:
        destination.append(i.text)
except NoSuchElementException:
    destination.append('NaN')
    
#duration
try:
    durations = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//p[@class = 'fs-12 bold du mb-2']")

    for i in durations:
        duration.append(i.text)
except NoSuchElementException:
    duration.append('NaN')  
    
    
#stops
try:
    stopss = driver.find_elements_by_xpath("//div[@class = 'stop-cont pl-13']//div[@class = ' font-lightgrey fs-10 tipsy i-b fs-10']//span")

    for i in stopss:
        stops.append(i.text)
except NoSuchElementException:
    stops.append('NaN')
    
    
#price
try:
    fares = driver.find_elements_by_xpath("//div[@class = 'i-b tipsy fare-summary-tooltip fs-18']")

    for i in fares:
        price.append(i.text)
except NoSuchElementException:
    price.append('NaN')

# %% [markdown]
# ## Saving Final Data

# %%
#DataFrame

Flight = pd.DataFrame()

Flight ['Name'] = name
Flight ['Date'] = date  
Flight ['Source'] = source
Flight ['Destination'] = destination             
Flight ['Dep_time'] = dep_time         
Flight ['Arr_time'] = arr_time
Flight ['Duration'] = duration
Flight ['Stops'] = stops
Flight ['Price'] = price

Flight
# Out:
#            Name         Date     Source Destination Dep_time        Arr_time  \
# 0      Air Asia  Sat, 27 Nov  New Delhi      Mumbai    20:00  02:25\n+ 1 day
# 1      Air Asia  Sat, 27 Nov  New Delhi      Mumbai    20:45  07:15\n+ 1 day
# 2      Air Asia  Sat, 27 Nov  New Delhi      Mumbai    20:00  07:40\n+ 1 day
# 3      Air Asia  Sat, 27 Nov  New Delhi      Mumbai    12:40  02:25\n+ 1 day
# 4      Go First  Sat, 27 Nov  New Delhi      Mumbai    21:10           23:15
# ...         ...          ...        ...         ...      ...             ...
# 1554    Vistara  Sun, 28 Nov  New Delhi     Chennai    13:20           23:05
# 1555     IndiGo  Sun, 28 Nov  New Delhi     Chennai    12:05           19:15
# 1556    Vistara  Sun, 28 Nov  New Delhi     Chennai    14:15           23:05
# 1557  Air India  Sun, 28 Nov  New Delhi     Chennai    11:00  10:55\n+ 1 day
# 1558  Air India  Sun, 28 Nov  New Delhi     Chennai    10:35  10:55\n+ 1 day
#
#      Duration      Stops   Price
# ...

# %%
Flight.to_csv('Flight_Price_Data.csv')
